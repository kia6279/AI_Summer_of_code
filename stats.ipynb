# %% [markdown]
# ## Agenda

# %% [markdown]
# - mean
# - median
# - mode

# %% [markdown]
# ## Again
# - iii
# - ggg
# - pppp

# %%
from scipy.stats import norm
from numpy import arange

# %%
range_new = arange(-3,3,0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 range_new = arange(-3,3,0.1)
#
# NameError: name 'arange' is not defined

# %%
test1 = norm.pdf()
